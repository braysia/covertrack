# %%
from os.path import dirname, join
import os, sys
COVERTRACK_PATH = dirname(os.path.abspath(os.curdir))
sys.path.append(COVERTRACK_PATH)
from segmentation.segment_utils.segment_param_optim import SegmentOptimizer
# %matplotlib inline

# %%
TEST_INPUT = join(dirname(COVERTRACK_PATH), 'input_file', 'input_tests1.py')
input_path = TEST_INPUT
segment_func = 'constant_lap_edge'

# %%
SegmentOptimizer(input_path, segment_func)
# Out:
# /Users/kudo/.pyenv/versions/anaconda-2.4.0/envs/covertrack/lib/python2.7/site-packages/numpy/core/numeric.py:190: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   a = empty(shape, dtype, order)
# /Users/kudo/.pyenv/versions/anaconda-2.4.0/envs/covertrack/lib/python2.7/site-packages/skimage/feature/peak.py:148: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   mask[:remove // 2] = mask[-remove // 2:] = False
# /Users/kudo/.pyenv/versions/anaconda-2.4.0/envs/covertrack/lib/python2.7/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint16
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/kudo/covertrack/covertrack/segmentation/segment_utils/segment_param_optim.py:307: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if image2==None:
